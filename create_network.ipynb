# %%
import osmnx as ox
import networkx as nx

# %matplotlib inline
ox.__version__
ox.settings.log_console=True

# %%
# create graph from .osm extract file
G = ox.graph_from_xml("./input_data/nordrhein-westfalen-latest.osm.bz2")
fig, ax = ox.plot_graph(G)

# %%
# query nominatim and overpass
place = {'city':'Dortmund', 'state':'NW', 'country':'Germany'}
G_DORTMUND = ox.graph_from_place(place, network_type="drive")
fig, ax = ox.plot_graph(G_DORTMUND)
